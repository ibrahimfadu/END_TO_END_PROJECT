# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import os
os.chdir("..")

df=pd.read_csv("data/comple_n1.csv")

# %%
df.head()
# Out:
#                                              COLLEGE  \
# 0  University of Visvesvaraya College of Engineering
# 1  University of Visvesvaraya College of Engineering
# 2  University of Visvesvaraya College of Engineering
# 3  University of Visvesvaraya College of Engineering
# 4  University of Visvesvaraya College of Engineering
#
#                        BRANCH CATEGORIES  Cutoff_2019  Cutoff_2020  \
# 0  AI Artificial Intelligence        2AG            0            0
# 1  AI Artificial Intelligence         GM            0            0
# 2  AI Artificial Intelligence        SCG            0            0
# 3  AI Artificial Intelligence        GMR            0            0
# 4  AI Artificial Intelligence        SCR            0            0
#
#    Cutoff_2021  Cutoff_2022  Cutoff_2023  Cutoff_2024
# 0            0          371        432.0          475
# 1            0          298        249.0          355
# 2            0          815       1733.0          670
# 3            0         1201          0.0            0
# 4            0            0          0.0            0

# %%
def recommend_colleges(rank, category, branch, df):
    # Filter by category & branch
    filtered_df = df[(df['CATEGORIES'] == category) & (df['BRANCH'] == branch)]
    
    # Find colleges where the cutoff is higher than the given rank
    recommended = filtered_df[filtered_df['Cutoff_Rank'] >= rank]
    
    return recommended[['COLLEGE', 'Cutoff_Rank']].sort_values(by="Cutoff_Rank")

# %%
category='GM'
branch='AI Artificial Intelligence'
filtered_df = df[(df['CATEGORIES'] == category) & (df['BRANCH'] == branch)]

# %%
df_copy=df.copy()

# %%
df_copy["Average"]=df[["Cutoff_2019","Cutoff_2020","Cutoff_2021","Cutoff_2022","Cutoff_2023","Cutoff_2024"]].mean(axis=1)

# %%
numerical_cols = df_copy.select_dtypes(include=['number'])

# Compute max for each row
df_copy["Max_Cutoff"] = numerical_cols.max(axis=1)
df_copy["Min_Cutoff"] = numerical_cols.min(axis=1)
df_copy
# Out:
#                                                COLLEGE  \
# 0    University of Visvesvaraya College of Engineering
# 1    University of Visvesvaraya College of Engineering
# 2    University of Visvesvaraya College of Engineering
# 3    University of Visvesvaraya College of Engineering
# 4    University of Visvesvaraya College of Engineering
# ..                                                 ...
# 355                  N M A M Institutute of Technology
# 356                  N M A M Institutute of Technology
# 357                  N M A M Institutute of Technology
# 358                  N M A M Institutute of Technology
# 359                  N M A M Institutute of Technology
#
#                          BRANCH CATEGORIES  Cutoff_2019  Cutoff_2020  \
# 0    AI Artificial Intelligence        2AG            0            0
# 1    AI Artificial Intelligence         GM            0            0
# 2    AI Artificial Intelligence        SCG            0            0
# 3    AI Artificial Intelligence        GMR            0            0
# 4    AI Artificial Intelligence        SCR            0            0
# ..                          ...        ...          ...          ...
# 355               ME Mechanical         GM         6159        15412
# 356               ME Mechanical        SCG         7762            0
# 357               ME Mechanical        GMR         6746            0
# 358               ME Mechanical        SCR            0            0
# 359               ME Mechanical        STG            0            0
#
#      Cutoff_2021  Cutoff_2022  Cutoff_2023  Cutoff_2024      Average  \
# 0              0          371        432.0          475   213.000000
# 1              0          298        249.0          355   150.333333
# 2              0          815       1733.0          670   536.333333
# 3              0         1201          0.0            0   200.166667
# 4              0            0          0.0            0     0.000000
# ..           ...          ...          ...          ...          ...
# 355        17306         2817       2912.0         3024  7938.333333
# 356            0         6138       6138.0         6138  4362.666667
# 357            0            0          0.0            0  1124.333333
# 358            0         7359       8890.0         9008  4209.500000
# 359            0            0          0.0            0     0.000000
#
#      Max_Cutoff  Min_Cutoff
# 0         475.0         0.0
# 1         355.0         0.0
# 2        1733.0         0.0
# 3        1201.0         0.0
# 4           0.0         0.0
# ..          ...         ...
# 355     17306.0      2817.0
# 356      7762.0         0.0
# 357      6746.0         0.0
# 358      9008.0         0.0
# 359         0.0         0.0
#
# [360 rows x 12 columns]

# %%
def recommend_college(rank, category, branch):
    # Filter colleges where cutoff is within a reasonable range
    filtered_df = df_copy[(df_copy['Average'] >= rank - 1000) & (df_copy['Average'] <= rank + 1000) & (df_copy['CATEGORIES'] == category) & (df_copy['BRANCH'] == branch)]
    
    # Sort by cutoff closest to the student's rank
    recommended_colleges = filtered_df.sort_values(by="Average", ascending=True)

    return recommended_colleges[['COLLEGE', 'Average']]

# Example: Get recommendations for a student
rank = 200
category = "GM"
branch = "AI Artificial Intelligence"

recommendations = recommend_college(rank, category, branch)
print(recommendations)
# Out:
#                                                COLLEGE     Average
# 181                 Siddaganga Institute of Technology    0.000000
# 217  JSS Science and Technology University(Formerly...    0.000000
# 253  K L E Dr. M S Sheshagiri College of Engineerin...    0.000000
# 289               K.L.S. Gogte Institute of Technology    0.000000
# 37                        R. V. College of Engineering   67.333333
# 1    University of Visvesvaraya College of Engineering  150.333333
# 325                  N M A M Institutute of Technology  312.833333
# 109         Sir M.Visveswaraya Institute of Technology  625.833333

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

x

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

df_copy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 7
#       4 from sklearn.compose import ColumnTransformer
#       5 from sklearn.pipeline import Pipeline
# ----> 7 x
#       9 x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#      11 df_copy
#
# NameError: name 'x' is not defined

# %%
college=
branch=
category=

# %%
df
# Out:
#                                                COLLEGE  \
# 0    University of Visvesvaraya College of Engineering
# 1    University of Visvesvaraya College of Engineering
# 2    University of Visvesvaraya College of Engineering
# 3    University of Visvesvaraya College of Engineering
# 4    University of Visvesvaraya College of Engineering
# ..                                                 ...
# 355                  N M A M Institutute of Technology
# 356                  N M A M Institutute of Technology
# 357                  N M A M Institutute of Technology
# 358                  N M A M Institutute of Technology
# 359                  N M A M Institutute of Technology
#
#                          BRANCH CATEGORIES  Cutoff_2019  Cutoff_2020  \
# 0    AI Artificial Intelligence        2AG            0            0
# 1    AI Artificial Intelligence         GM            0            0
# 2    AI Artificial Intelligence        SCG            0            0
# 3    AI Artificial Intelligence        GMR            0            0
# 4    AI Artificial Intelligence        SCR            0            0
# ..                          ...        ...          ...          ...
# 355               ME Mechanical         GM         6159        15412
# 356               ME Mechanical        SCG         7762            0
# 357               ME Mechanical        GMR         6746            0
# 358               ME Mechanical        SCR            0            0
# 359               ME Mechanical        STG            0            0
#
#      Cutoff_2021  Cutoff_2022  Cutoff_2023  Cutoff_2024
# 0              0          371        432.0          475
# 1              0          298        249.0          355
# 2              0          815       1733.0          670
# 3              0         1201          0.0            0
# 4              0            0          0.0            0
# ..           ...          ...          ...          ...
# 355        17306         2817       2912.0         3024
# 356            0         6138       6138.0         6138
# 357            0            0          0.0            0
# 358            0         7359       8890.0         9008
# 359            0            0          0.0            0
#
# [360 rows x 9 columns]

# %%
sns.scatterplot(x="Cutoff_2019",y="COLLEGE",data=df)
# Out:
# <Axes: xlabel='Cutoff_2019', ylabel='COLLEGE'>

# %%
df["COLLEGE"].unique()
# Out:
# array(['University of Visvesvaraya College of Engineering',
#        'R. V. College of Engineering',
#        'Dayananda Sagar College of Engineering',
#        'Sir M.Visveswaraya Institute of Technology',
#        'S J C Institute of Technology',
#        'Siddaganga Institute of Technology',
#        'JSS Science and Technology University(Formerly SJCE)',
#        'K L E Dr. M S Sheshagiri College of Engineering and Technology',
#        'K.L.S. Gogte Institute of Technology',
#        'N M A M Institutute of Technology'], dtype=object)

# %%
df["BRANCH"].unique()
# Out:
# array(['AI Artificial Intelligence', 'CE Civil', 'CS Computers',
#        'EC Electronics', 'EE Electrical', 'ME Mechanical'], dtype=object)

# %%
df["CATEGORIES"].unique()
# Out:
# array(['2AG', 'GM', 'SCG', 'GMR', 'SCR', 'STG'], dtype=object)

# %%
colleges=['R. V. College of Engineering','Dayananda Sagar College of Engineering']

branchs='CS Computers'

categorys='GM'

# %%
for college,branch,category in zip(colleges,branchs,categorys):
    filter=df.loc[(df["COLLEGE"]==colleges)&(df["BRANCH"]==branchs)&(df["CATEGORIES"]==categorys),["Cutoff_2019","Cutoff_2020","Cutoff_2021","Cutoff_2022","Cutoff_2023","Cutoff_2024"]].values
    print(filter)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 2
#       1 for college,branch,category in zip(colleges,branchs,categorys):
# ----> 2     filter=df.loc[(df["COLLEGE"]==colleges)&(df["BRANCH"]==branchs)&(df["CATEGORIES"]==categorys),["Cutoff_2019","Cutoff_2020","Cutoff_2021","Cutoff_2022","Cutoff_2023","Cutoff_2024"]].values
#       3     print(filter)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:5803, in Series._cmp_method(self, other, op)
#    5800 lvalues = self._values
#    5801 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5803 res_values = ops.comparison_op(lvalues, rvalues, op)
#    5805 return self._construct_result(res_values, name=res_name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py:323, in comparison_op(left, right, op)
#     318 if isinstance(rvalues, (np.ndarray, ABCExtensionArray)):
#     319     # TODO: make this treatment consistent across ops and classes.
#     320     #  We are not catching all listlikes here (e.g. frozenset, tuple)
#     321     #  The ambiguous case is object-dtype.  See GH#27803
#     322     if len(lvalues) != len(rvalues):
# --> 323         raise ValueError(
#     324             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     325         )
#     327 if should_extension_dispatch(lvalues, rvalues) or (
#     328     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     329     and lvalues.dtype != object
#     330 ):
#     331     # Call the method on lvalues
#     332     res_values = op(lvalues, rvalues)
#
# ValueError: ('Lengths must match to compare', (360,), (2,))

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_cutoff_trend(df, colleges, branch, category):
    """
    Plots a line chart comparing cutoff trends from 2019 to 2024 for multiple colleges.

    Parameters:
        df (pd.DataFrame): The dataset containing cutoff data.
        colleges (list): List of college names to compare.
        branch (str): Selected branch.
        category (str): Selected category.
    """
    # Define cutoff year columns
    cutoff_years = ["Cutoff_2019", "Cutoff_2020", "Cutoff_2021", "Cutoff_2022", "Cutoff_2023", "Cutoff_2024"]
    
    # Filter data based on branch, category, and selected colleges
    filtered_df = df[
        (df["BRANCH"] == branch) & 
        (df["CATEGORIES"] == category) & 
        (df["COLLEGE"].isin(colleges))
    ]

    # Check if data is available
    if filtered_df.empty:
        print("No data found for the given inputs.")
        return
    
    # Plot cutoff trends for each selected college
    plt.figure(figsize=(10, 6))
    
    for _, row in filtered_df.iterrows():
        plt.plot(cutoff_years, row[cutoff_years], marker="o", linestyle="-", label=row["COLLEGE"])

    # Customize the plot
    plt.xlabel("Year")
    plt.ylabel("Cutoff Score")
    plt.title(f"Cutoff Trend (2019-2024) for {branch}, {category}")
    plt.xticks(rotation=45)
    plt.legend(title="Colleges")
    plt.grid(axis="y", linestyle="--", alpha=0.7)

    # Display the plot
    plt.show()

# %%
plot_cutoff_trend(df,colleges,branchs,categorys)
